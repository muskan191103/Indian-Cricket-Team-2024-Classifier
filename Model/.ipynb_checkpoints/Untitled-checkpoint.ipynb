# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/arshdeep_singh.jpeg')
img.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (225, 225)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[71, 49, 78, 78]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (71, 49, 78, 78)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
face_img = img.copy()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    # Check if eyes are detected
    if len(eyes) == 0:
        print("No eyes detected in the face region.")
    else:
        print(f"Detected {len(eyes)} eye(s) in the face region.")
        
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure()
plt.imshow(face_img, cmap='gray')
# plt.imshow(cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Detected 2 eye(s) in the face region.

# %%
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if (len(eyes)>=2):
            return roi_color

# %%
def get_cropped_image_if_2_eyes1(image_path):
    img = cv2.imread(image_path)

    if img is None:
        print(f"Failed to read image at path: {image_path}")
        return []
        
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3,5)

    faces_list = []
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if (len(eyes)>=2):
            faces_list.append(roi_color)

    return faces_list

# %%
o_img = cv2.imread('./test_images/arshdeep_singh.jpeg')
plt.imshow(o_img)

# %%
cropped_img = get_cropped_image_if_2_eyes('./test_images/arshdeep_singh.jpeg')
plt.imshow(cropped_img)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Arshdeep Singh',
#  './dataset/Axar Patel',
#  './dataset/cropped',
#  './dataset/Hardik Pandya',
#  './dataset/Jasprit Bumrah',
#  './dataset/Kuldeep Yadav',
#  './dataset/Mohammed Siraj',
#  './dataset/Ravindra Jadeja',
#  './dataset/Rishabh Pant',
#  './dataset/Rohit Sharma',
#  './dataset/Sanju Samson',
#  './dataset/Shivam Dube',
#  './dataset/Suryakumar yadav',
#  './dataset/Virat Kohli',
#  './dataset/Yashasvi Jaiswal',
#  './dataset/Yuzvendra Chahal']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)

os.mkdir(path_to_cr_data)

# %%
cropped_img_dirs = []
cricketers_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    cricketer_name = img_dir.split('/')[-1]

    for entry in os.scandir(img_dir):
        print(f"Processing file: {entry.path}")
        roi_color_list = get_cropped_image_if_2_eyes1(entry.path)
        for roi_color in roi_color_list:
            
            if roi_color is not None:
                cropped_folder = path_to_cr_data + cricketer_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_img_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ",cropped_folder)
    
                cropped_file_name = cricketer_name + str(count) + ".png"
                cropped_file_path = cropped_folder + "/" + cropped_file_name
    
                cv2.imwrite(cropped_file_path, roi_color)
                cricketers_file_names_dict[cricketer_name].append(cropped_file_path)
                count +=1
# Out:
# Processing file: ./dataset/Arshdeep Singh\image_11.jpg
# Processing file: ./dataset/Arshdeep Singh\image_14.jpeg
# Processing file: ./dataset/Arshdeep Singh\image_16.jpeg
# Processing file: ./dataset/Arshdeep Singh\image_18.jpeg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 24
#      21 cropped_file_path = cropped_folder + "/" + cropped_file_name
#      23 cv2.imwrite(cropped_file_path, roi_color)
# ---> 24 cricketers_file_names_dict[cricketer_name].append(cropped_file_path)
#      25 count +=1
#
# TypeError: list indices must be integers or slices, not str

# %%
cropped_img_dirs = []
cricketers_file_names_dict = []

for img_dir in img_dirs:
    count = 1
    cricketer_name = img_dir.split('/')[-1]

    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + cricketer_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_img_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)

            cropped_file_name = cricketer_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name

            cv2.imwrite(cropped_file_path, roi_color)
            count +=1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Arshdeep Singh
# Generating cropped images in folder:  ./dataset/cropped/Axar Patel
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[71], line 9
#       6 cricketer_name = img_dir.split('/')[-1]
#       8 for entry in os.scandir(img_dir):
# ----> 9     roi_color = get_cropped_image_if_2_eyes(entry.path)
#      10     if roi_color is not None:
#      11         cropped_folder = path_to_cr_data + cricketer_name
#
# Cell In[64], line 3, in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       2     img = cv2.imread(image_path)
# ----> 3     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4     faces = face_cascade.detectMultiScale(gray, 1.3,5)
#       5     for (x,y,w,h) in faces:
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
